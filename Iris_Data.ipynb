# %%
import numpy as np
import pandas as pd
import sklearn as sk

# %%
irisData = pd.read_csv("mlfolder/CSV_Files/iris_dataset_with_class_information.csv")

# %%
irisData.shape
# Out:
# (150, 5)

# %%
print(type(irisData))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
irisData
# Out:
#      sepal.length.in.cm  sepal.width.in.cm  petal.length.in.cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal.width.in.cm    species
# 0                  0.2     setosa
# 1                  0.2     setosa
# 2                  0.2     setosa
# 3                  0.2     setosa
# ...

# %%
X1 = irisData["sepal.length.in.cm"]

# %%
X1
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal.length.in.cm, Length: 150, dtype: float64

# %%
X2 = irisData[["sepal.length.in.cm", "sepal.width.in.cm"]]

# %%
X2
# Out:
#      sepal.length.in.cm  sepal.width.in.cm
# 0                   5.1                3.5
# 1                   4.9                3.0
# 2                   4.7                3.2
# 3                   4.6                3.1
# 4                   5.0                3.6
# ..                  ...                ...
# 145                 6.7                3.0
# 146                 6.3                2.5
# 147                 6.5                3.0
# 148                 6.2                3.4
# 149                 5.9                3.0
#
# [150 rows x 2 columns]

# %%
irisData.iloc[0:10,  0:5] #first 10 rows,second range indicate first 5 columns
# Out:
#    sepal.length.in.cm  sepal.width.in.cm  petal.length.in.cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
# 5                 5.4                3.9                 1.7
# 6                 4.6                3.4                 1.4
# 7                 5.0                3.4                 1.5
# 8                 4.4                2.9                 1.4
# 9                 4.9                3.1                 1.5
#
#    petal.width.in.cm species
# 0                0.2  setosa
# 1                0.2  setosa
# 2                0.2  setosa
# 3                0.2  setosa
# 4                0.2  setosa
# 5                0.4  setosa
# 6                0.3  setosa
# 7                0.2  setosa
# ...

# %%
irisData.iloc[:10, :5]
# Out:
#    sepal.length.in.cm  sepal.width.in.cm  petal.length.in.cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
# 5                 5.4                3.9                 1.7
# 6                 4.6                3.4                 1.4
# 7                 5.0                3.4                 1.5
# 8                 4.4                2.9                 1.4
# 9                 4.9                3.1                 1.5
#
#    petal.width.in.cm species
# 0                0.2  setosa
# 1                0.2  setosa
# 2                0.2  setosa
# 3                0.2  setosa
# 4                0.2  setosa
# 5                0.4  setosa
# 6                0.3  setosa
# 7                0.2  setosa
# ...

# %%
irisData.iloc[145:, 1:]
# Out:
#      sepal.width.in.cm  petal.length.in.cm  petal.width.in.cm    species
# 145                3.0                 5.2                2.3  virginica
# 146                2.5                 5.0                1.9  virginica
# 147                3.0                 5.2                2.0  virginica
# 148                3.4                 5.4                2.3  virginica
# 149                3.0                 5.1                1.8  virginica

# %%
irisData.columns = ["sepalLength", "sepalWidth", "petalLength", "petalWidth", "Class"]

# %%
irisData.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth   Class
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
sns.scatterplot(x='sepalLength', y='sepalWidth', data=irisData, hue='Class')
# Out:
# <Axes: xlabel='sepalLength', ylabel='sepalWidth'>

# %%
sns.scatterplot(x='petalLength',y='petalWidth',data=irisData,hue='Class')
# Out:
# <Axes: xlabel='petalLength', ylabel='petalWidth'>

# %%
sns.scatterplot(x='petalLength',y='petalWidth',data=irisData,size='Class',hue='Class')
# Out:
# <Axes: xlabel='petalLength', ylabel='petalWidth'>

# %%
#Shuffling Data
X = irisData.sample(frac=1, random_state=12).reset_index(drop=True)

# %%
X
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth       Class
# 0            5.0         3.5          1.3         0.3      setosa
# 1            6.3         2.5          5.0         1.9   virginica
# 2            4.4         3.0          1.3         0.2      setosa
# 3            5.7         2.8          4.1         1.3  versicolor
# 4            6.8         3.2          5.9         2.3   virginica
# ..           ...         ...          ...         ...         ...
# 145          6.8         2.8          4.8         1.4  versicolor
# 146          4.6         3.1          1.5         0.2      setosa
# 147          7.4         2.8          6.1         1.9   virginica
# 148          6.1         2.6          5.6         1.4   virginica
# 149          6.6         3.0          4.4         1.4  versicolor
#
# [150 rows x 5 columns]

# %%
trainData = X.iloc[:120, :5] #120 rows out of 150 80% data

# %%
trainData
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth       Class
# 0            5.0         3.5          1.3         0.3      setosa
# 1            6.3         2.5          5.0         1.9   virginica
# 2            4.4         3.0          1.3         0.2      setosa
# 3            5.7         2.8          4.1         1.3  versicolor
# 4            6.8         3.2          5.9         2.3   virginica
# ..           ...         ...          ...         ...         ...
# 115          5.7         2.6          3.5         1.0  versicolor
# 116          5.6         3.0          4.1         1.3  versicolor
# 117          6.5         3.0          5.2         2.0   virginica
# 118          5.8         2.7          5.1         1.9   virginica
# 119          5.2         2.7          3.9         1.4  versicolor
#
# [120 rows x 5 columns]

# %%
testData = X.iloc[120:,0:5] #30 rows i,e 20% data for testing

# %%
testData
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth       Class
# 120          5.2         3.5          1.5         0.2      setosa
# 121          6.5         3.2          5.1         2.0   virginica
# 122          5.2         4.1          1.5         0.1      setosa
# 123          6.8         3.0          5.5         2.1   virginica
# 124          4.8         3.1          1.6         0.2      setosa
# 125          4.8         3.0          1.4         0.3      setosa
# 126          6.1         2.8          4.7         1.2  versicolor
# 127          7.2         3.6          6.1         2.5   virginica
# 128          6.3         2.7          4.9         1.8   virginica
# 129          5.7         2.9          4.2         1.3  versicolor
# 130          6.0         2.2          5.0         1.5   virginica
# 131          6.3         3.3          6.0         2.5   virginica
# 132          5.0         3.2          1.2         0.2      setosa
# ...

# %%
xTrain = trainData.iloc[:,:4]

# %%
xTrain.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth
# 0          5.0         3.5          1.3         0.3
# 1          6.3         2.5          5.0         1.9
# 2          4.4         3.0          1.3         0.2
# 3          5.7         2.8          4.1         1.3
# 4          6.8         3.2          5.9         2.3

# %%
yTrain = trainData.iloc[:,4]

# %%
yTrain.head()
# Out:
# 0        setosa
# 1     virginica
# 2        setosa
# 3    versicolor
# 4     virginica
# Name: Class, dtype: object

# %%
xTest = testData.iloc[:,:4]

# %%
xTest.head()
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth
# 120          5.2         3.5          1.5         0.2
# 121          6.5         3.2          5.1         2.0
# 122          5.2         4.1          1.5         0.1
# 123          6.8         3.0          5.5         2.1
# 124          4.8         3.1          1.6         0.2

# %%
yTest = testData.iloc[:,4]

# %%
yTest.head()
# Out:
# 120       setosa
# 121    virginica
# 122       setosa
# 123    virginica
# 124       setosa
# Name: Class, dtype: object

# %% [markdown]
# Naive Bayes Classification

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(xTrain,yTrain)
# Out:
# GaussianNB()

# %%
modelPrediction = model.predict(xTest)

# %%
modelPrediction
# Out:
# array(['setosa', 'virginica', 'setosa', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'virginica', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'versicolor', 'versicolor', 'setosa',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'virginica',
#        'virginica', 'versicolor', 'setosa', 'setosa', 'versicolor',
#        'setosa', 'virginica', 'versicolor', 'versicolor'], dtype='<U10')

# %%
np.sum(yTest == modelPrediction)
# Out:
# np.int64(27)

# %%
modelPrediction.shape
# Out:
# (30,)

# %%
pd.set_option("display.max_rows",200)

# %%
yTest==modelPrediction
# Out:
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# 128     True
# 129     True
# 130    False
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
# 136     True
# 137     True
# 138     True
# 139     True
# 140     True
# 141     True
# 142    False
# 143     True
# 144     True
# 145     True
# 146     True
# 147     True
# 148    False
# 149     True
# Name: Class, dtype: bool

# %%
yTest.size
# Out:
# 30

# %%
(np.sum(yTest == modelPrediction))/yTest.size
# Out:
# np.float64(0.9)

# %%
pd.get_option("display.max_rows")
# Out:
# 200

# %%
pd.reset_option("display.max_rows")

# %%
pd.get_option("display.max_rows")
# Out:
# 60
